# %%
import torch 
import torch.nn as nn
import numpy as np
from rdkit import Chem
from rdkit import rdBase
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import random
import re
from torch.utils.data import DataLoader,Dataset
from scoring_functions import get_scoring_function
import torch.nn.functional as F
print(torch.__version__)
# Out:
# 2.0.0

# %% [markdown]
# # data process

# %%
def replace_halogen(string):
    """Regex to replace Br and Cl with single letters"""
    br = re.compile('Br')
    cl = re.compile('Cl')
    string = br.sub('R', string)
    string = cl.sub('L', string)

    return string

class Vocabulary:
    def __init__(self,file,max_len=140):
        self.file = file
        self.max_len = max_len
        self.vocab_size,self.vocab,self.reversed_vocab = self.get_voc(file)
        self.reversed_vocab = {v: k for k, v in self.vocab.items()}
        self.max_len = max_len
    
    def get_voc(self,file):
        with open(file, 'r') as f:
            chars = f.read().split()
        chars +=  ['EOS', 'GO']
        chars.sort()
        vocab_size = len(chars)
        vocab = dict(zip(chars, range(len(chars))))
        reversed_vocab = {v: k for k, v in vocab.items()}
        return vocab_size,vocab,reversed_vocab
        
    def tokenize(self, smiles):
        """Takes a SMILES and return a list of characters/tokens"""
        regex = '(\[[^\[\]]{1,6}\])'
        smiles = replace_halogen(smiles)
        char_list = re.split(regex, smiles)
        tokenized = []
        for char in char_list:
            if char.startswith('['):
                tokenized.append(char)
            else:
                chars = [unit for unit in char]
                [tokenized.append(unit) for unit in chars]
        tokenized.append('EOS')
        return tokenized
    
    def encode(self,char_list):
        smiles_matrix = np.zeros(len(char_list), dtype=np.float32)
        for i, char in enumerate(char_list):
            smiles_matrix[i] = self.vocab[char]
        return smiles_matrix
    
    def decode(self,matrix):
        chars = []
        for i in matrix:
            i = i.item()
            if i == self.vocab['EOS']: break
            chars.append(self.reversed_vocab[i])
        smiles = "".join(chars)
        smiles = smiles.replace("L", "Cl").replace("R", "Br")
        return smiles
                          
    def __len__(self):
        return len(self.chars)

    def __str__(self):
        return "Vocabulary containing {} tokens: {}".format(len(self), self.chars)
    
class MolData(Dataset):
    """Custom PyTorch Dataset that takes a file containing SMILES.

        Args:
                fname : path to a file containing \n separated SMILES.
                voc   : a Vocabulary instance

        Returns:
                A custom PyTorch dataset for training the Prior.
    """
    def __init__(self, fname, voc):
        self.voc = voc
        self.smiles = []
        with open(fname, 'r') as f:
            for line in f:
                self.smiles.append(line.split()[0])

    def __getitem__(self, i):
        mol = self.smiles[i]
        tokenized = self.voc.tokenize(mol)
        encoded = self.voc.encode(tokenized)
        return encoded

    def __len__(self):
        return len(self.smiles)

    def __str__(self):
        return "Dataset containing {} structures.".format(len(self))

    @classmethod
    def collate_fn(cls, arr):
        """Function to take a list of encoded sequences and turn them into a batch"""
        max_length = max([seq.size for seq in arr])
        collated_arr = np.zeros((len(arr), max_length))
        for i, seq in enumerate(arr):
            collated_arr[i, :seq.size] = seq
        return torch.from_numpy(collated_arr)

# %% [markdown]
# # define model

# %%
class GRULayer(nn.Module):
    def __init__(self, voc_size):
        super().__init__()
        self.embedding = nn.Embedding(voc_size,128)
        self.gru1 = nn.GRUCell(128,512)
        self.gru2 = nn.GRUCell(512,512)
        self.gru3 = nn.GRUCell(512,512)
        self.fcn = nn.Linear(512,voc_size)
        
    def forward(self, x, h):
        x = x.to(device)
        h = h.to(device)
        h_out = torch.zeros(h.shape).to(device)
        x = self.embedding(x).to(device)
        x = h_out[0] = self.gru1(x,h[0])
        x = h_out[1] = self.gru2(x,h[1])
        x = h_out[2] = self.gru3(x,h[2])
        x = self.fcn(x)
        return x,h_out

class RNN():
    def __init__(self,voc,batch_size,max_len=140):
        global device
        self.rnn = GRULayer(voc.vocab_size).to(device)
        self.voc = voc
        self.batch_size = batch_size
        self.max_len = max_len
        self.loss_fn = nn.BCELoss(reduction='none')
    
    def bce_loss(self,prob,target):
        onehot_target = torch.zeros(prob.shape).to(device)
        onehot_target.scatter_(1, target.contiguous().view(-1, 1).data, 1.0)
        onehot_target = onehot_target.to(device)
        return self.loss_fn(prob,onehot_target)
    
    def forward(self,target):
        self.rnn.train()
        outs = []
        loss = 0
        target = target.to(device)
        h = torch.zeros(3, self.batch_size, 512).float()
        start_token = torch.zeros(self.batch_size,1).long().to(device)
        start_token[:] = self.voc.vocab['GO']
        x = torch.cat((start_token, target[:, :-1]), 1)
        for step in range(target.shape[1]):
            logits,h = self.rnn(x[:, step],h)
            prob = F.softmax(logits,dim=1)
            out = torch.argmax(prob,dim=1)
            outs.append(out)
            loss += self.bce_loss(prob, target[:, step])
        outs = torch.transpose(torch.stack(outs),1,0)
        acc = torch.sum(outs==target.to(device))/outs.numel()
        return loss,acc
    
    def sample(self,batch_size):
        output = []
        loss = 0
        h = torch.zeros(3, batch_size, 512).float()
        start_token = torch.zeros(batch_size).long()
        start_token[:] = self.voc.vocab['GO']
        x = start_token
        finished = torch.zeros(batch_size).byte().to(device)
        with torch.no_grad():
            self.rnn.eval()
            for step in range(self.max_len):
                logits,h = self.rnn(x,h)
                prob = F.softmax(logits,dim=1)
                x = torch.multinomial(prob, num_samples=1).view(-1)
                output.append(x.view(-1, 1))
                loss += self.bce_loss(prob, x.to(device))
                EOS_sampled = (x == self.voc.vocab['EOS']).byte()
                finished = torch.ge(finished + EOS_sampled, 1)
                if torch.prod(finished) == 1: break
                
        return torch.cat(output, 1),loss

# %%
num_epoch = 5
batch_size = 256
lr = 2e-3
device = "cuda" if torch.cuda.is_available() else 'cpu'

# %%
voc = Vocabulary("data/Voc")
moldata = MolData("data/ChEMBL_filtered", voc)
data = DataLoader(moldata, batch_size=batch_size, shuffle=True, drop_last=True,collate_fn=MolData.collate_fn)
model = RNN(voc,batch_size)
optimizer = torch.optim.Adam(model.rnn.parameters(), lr = lr)
lr_scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer,lambda x: 1 - x/(len(data)*num_epoch),last_epoch=-1)

# %%
for epoch in range(num_epoch):
    bar = tqdm(enumerate(data), total=len(data))
    bar.set_description(f'[ Epoch: {epoch+1}]')
    for step,batch in bar:
        optimizer.zero_grad()
        seqs = batch.long()
        loss,acc = model.forward(seqs)
        loss = loss.mean()
        loss.backward()
        optimizer.step()
        lr_scheduler.step()
        bar.set_postfix({"loss":loss.item(),'acc':acc.item()})
        
        if (step+1) % 200 ==0:
            seqs,_ = model.sample(batch_size)
            tqdm.write(f'-------{step+1}--------')
            valid = 0
            for i,seq in enumerate(seqs):
                smile = voc.decode(seq)
                smile = voc.decode(seq)
                if Chem.MolFromSmiles(smile):
                    valid += 1
                if i < 5:
                    tqdm.write(smile)
            tqdm.write("\n{:>4.1f}% valid SMILES".format(100 * valid / len(seqs)))
            torch.save(model.rnn.state_dict(), "data/Prior.ckpt")
        torch.save(model.rnn.state_dict(), "data/Prior.ckpt")
# Out:
#   0%|          | 0/4607 [00:00<?, ?it/s]
# -------200--------
# COc1ccc([O-])cc1CNC(=O)C(Cc1ccccc1)c1ccsc1
# COc1cccc(C(=O)NC(COc2cncn2)c1CCN(Cc1ccc(F)cc1)NC2=CC(=O)c1ccccc1
# COc1cccc(NC(=O)COCC2=Nc3c(O)nc(-n5nc(C(=O)N3CCOCC55)c3)n2C)n1
# CCOC(=O)CCOC(=O)C1(N1=CCC(=O)c2cccc(C(=O)NCc3ccccc3)c(=O)c2cc(O)ccc21
# Cn1c(NCCNn2cccc2Nc2nc3ccccc3c4c(c2)NCC1CN3
#
#  6.6% valid SMILES
# -------400--------
# COC(=O)C1=CC(=O)C(=Cc2ccc(O)cc2)N1Cc1cccs1
# Cc1ccc(NC(=O)C=Cc2ccc3c(cc2OC)OO4)cc1
# Cc1cccnc1Nc1ccc(-n2c(C#N)c3c(N)nccc32)cc1
# COC(=O)c1cccc(-c2cc(CS(C)(=O)=O)ccc2N2CCC(O)CC2)c1
# CCNC(=O)CSCC(NC(=O)CNC(=O)c1c2ccccc2Cl)cc1C(=O)OCC(Oc1ccccc1)C(C)C
#
# 45.7% valid SMILES
# -------600--------
# Cc1ccc(CNN=c2nn3n(C)c4ccccc4c3nn2)cc1
# COC1CC(=O)OC(c2ccc(OC(=O)O)cc2)CC1Cc1ccncc1
# CCOc1cc(CNC(=S)NC#N)cc(Br)c1O
# O=C1NC(c2ccc(Cl)cc2)N1CCOc1nccnc1Sc1cccc([S+]([O-])(F)F)c1
# Cc1cccc(C2(Cn3cnc(NC(C)(C)C)n3)CN(C)CC(C)NC(C)C)N2S(=O)(=O)c2cccc(N)c2)c1
#
# 48.8% valid SMILES
# -------800--------
# c1ccc2nnc(C#CC3=NCCc4c[nH]c(N)n4)cc3c2(O)C1CC1
# CC(=O)NCc1ccnc(N=C2SC(CN(CC(=O)c3ccccc3)N3CCC(CO)CC3)(CCl)C2)c1
# O=c1c[nH]c2ccccc2c1OC1(c2ccc3c(cc3[N+](=O)c3ccccc3F)CCN2C2=O)CC1
# CC(=O)Nc1ccc(NCC2CCCNc2ncc(-c3ccc(Cc4cccc(OC)c4)cc3)s2)cc1
# O=C(Nc1ccc(S(=O)(=O)N(C)C(=O)C(C=Cc2cc[n+](=O)[nH]c2=O)C2CCC(c3ncccc3)CC2)c2ccccc12)NCc1ccccc1F
#
# 63.3% valid SMILES
# -------1000--------
# Brc1ccc(CNC(=O)Cn2c(=O)c3cc(Br)c3c4ccccc4n3c(=O)c4c3ccc3[nH][n+](c4c3)CCS2)[nH]1
# COc1ccccc1N1CCN(C(=O)c2cccc(C#CC(N)=O)c2)CC1
# CCOc1ccc(OC)c(S(=O)(=O)Nc2cccnc2-c2ccccc2)c1
# Cc1ccccc1C(=O)Nc1cnn(C)n1
# N=C(N)c1ccc(CCc2ccccc2)cc1
#
# 63.7% valid SMILES
# -------1200--------
# CN1c2ccc(C(=O)NCc3cc(C)c(OC)c(OC)c3)ccc2C(CN(C)C)N1C
# Cc1c(C#N)c(N)c(CSc2nnc(-c3cccs3)n2-c2ccc(F)cc2)s1
# CC(C)(C)C(=O)NC(CC(=O)O)C(=O)O
# O=C(OC1C[N+]([O-])=C(F)C(O)C1O)c1ncccc1O
# CCc1ccc(S(CC(=O)Nc2ccc(C(N)=O)cc2)c2ccccc2)c(N)n1
#
# 73.4% valid SMILES
# -------1400--------
# Cc1ccc(CN2CCN(c3cccc(C#N)c3)CC2)cc1
# CCOc1ccc(NC(=O)CCNC(C)c2ccccn2)cc1
# COC(=O)C1=C(O)Oc2cccc(OC[n+]3cccc4ccccc34)c21
# O=C1c2ccc(-c3cc(-c4ccc(O)cc4)on3)cc2C(=O)N1CCNS(=O)(=O)c1cccc(Cl)c1
# CC(C)CC(NC(C)c1ccc(OCC(F)(F)F)nc1)c1nc(-c2ccccc2)nn1C
#
# 70.3% valid SMILES
# -------1600--------
# CC(C)c1ccc2c(c1)N(CN1CC(c3ccccc3)c3ccccc31)C(c1ccc(C(=O)O)cc1)=C(O)C2
# O=C(OCc1ccccc1[N+](=O)[O-])Nc1ccc([N+](=O)[O-])cc1
# O=C(Nc1scnc1CN(C(=O)c1ccccc1)C1CC1
# COC1(c2c(F)cc3c(F)cc(F)cc3c2=O)CCC2CCC3(C)C(=CCC4OO5)C(C)(C)C3CCC2C1
# CC1(C(=O)Nc2ncns2)CCN1C(=O)C=CC(C)(
#
# 72.7% valid SMILES
# -------1800--------
# Oc1ccc2c(=O)c3ccccc3n(CCN3CCN(c4ccccc4)CC3)c2c1
# CCOC(=O)c1coc(Nc2ccccc2)n1
# CCCOC(=O)C1=C(N)Oc2cccc3ccc(N)c3c2C(=O)CC(C(O)=C(C)C)N(C(C)=O)C1=O
# O=[N+]([O-])c1cnccc1N1CCOCC1(CN1CCOCC1)Cc1ccc(OCc2ccc3c(c2)O(COCCO)CC3)cc1
# C=C1CCC2(O)C(CO)CCC(OC1=O)C(CO)C2OC(C)=COC=O
#
# 75.0% valid SMILES
# -------2000--------
# CC(=NOCC(=O)Nc1cccc2ccccc12)c1ccc(F)cc1
# Cc1oc2cc(O)cc(C3OC(CO)C(O)C(O)C3O)c2c1
# Cc1ccc(S(=O)(=O)NCCCN2CCC(F)CC2)cc1
# CCc1c(OCC(O)CNC(CO)C(F)(F)F)nn2c1CCC3C(=O)OCc1ccccc1
# CC1=CC23CCC(C(=O)N(Cc4ccc(F)cc4)C3(S(=O)(=O)c3ccccc3F)CC2NC1=O
#
# 75.4% valid SMILES
# -------2200--------
# COc1ccc(N=Nc2nc(-c3ccccc3)c3ccccc3n2)cc1
# COC12C(CO)C(N3Cc4ccccc4C3)C(=O)C=C1N2CCOC(=O)C1CC1
# COC(=O)c1c(C)[nH]c(C(=O)C=Cc2ccc(F)cc2)c1-c1ccc(C)cc1
# O=C(NCc1cccnc1-c1cc(F)ccc1F)c1ccccc1Cl
# CN(c1ccc(Cl)cc1)S(=O)(=O)c1ccc(N(CCCl)CCCl)cc1C
#
# 75.8% valid SMILES
# -------2400--------
# COc1cc(C=Cc2ccc(O)cc2)cc(OC)c1O
# O=C(O)c1ccccc1Cn1ccnc1
# COc1cc2ccccc2cc1C(=O)NCCc1cc(OC)c(OC)cc1OC
# COC(=O)c1cc2ccccc2[nH]1
# O=c1c(C2=NS(=O)(=O)c3cccc(S(=O)(=O)N4CCc5ccccc54)cc3)CC2)cc2ccc(Cl)cc12
#
# 81.6% valid SMILES
# -------2600--------
# Cc1ccc(NC(=O)CNC(=O)CCc2nn3ccncc3c2F)cc1Cc1ccccc1
# O=c1[nH]nc(-c2ccccc2)n1N=Cc1ccc(O)c(CCF)n1
# O=C(Oc1ccc2c(c1)OCCO2)c1cnn(-c2ccccc2)c1=O
# COc1ccc(CN2CCC3(CCN(C(=O)c4ccncc4)CC3)CC2Cc2ccccc2)c(OC)c1
# Cn1nnnc1SCC1=C(C(=O)O)N2C(=O)C(NC(=O)C(C(=O)O)CSC=C(N)C3O)OC21
#
# 78.1% valid SMILES
# -------2800--------
# CN(Cc1ccc2nc(-c3ccnc(N4Cc5ccccc5C4)CC3)cn2c1)c1ccccc1Cl
# O=C1CC(c2ccccc2)=NC(c2ccccc2)=NC1
# O=C(N1Cc2ccccc2C1)n1c(=O)c(C(=O)Nc2ccc(Cl)c(Cl)c2)nc2ccccc21
# CN1CCOC=C(c2ccc(Br)cc2)C1
# CC(=O)N1CCC2(CCC(c3cccc(C(F)(F)F)c3)CC2)=N1
#
# 73.0% valid SMILES
# -------3000--------
# COc1ccc(O)c(-c2nc3ccc(-c4ccc(F)cc4)cc3s2)c1
# CCOc1ccc(C=Cc2cc(OC)cc(OC)c2C2CN(Cc3ccoc3)CCS2)cc1OC
# COc1ccc(O)c(OC(=O)CC)c1
# COc1ccc(-c2cc3c(N4CCN(CC)CC4)C(=O)cc(=O)[nH]c3c2Cl)cc1
# CC1(C)N=C(N)Oc2cccc3c2C13C(=O)N(C)C(=O)NC(C(=O)NCCCNCC=C(C(=O)O)CC(C)(C)O)C3
#
# 82.0% valid SMILES
# -------3200--------
# CCCn1c(=O)c(-c2ccc(Cl)cc2)nn(CC)c1=O
# CC(C)CCN=C(S)NC(=O)c1cc(C2CC2)c(O)c(C(C)(C)C)c1
# CCN(CCc1ccc(NS(=O)(=O)c2ccc(C)cc2)cc1)CC(O)c1ncnc2cc(F)c(F)cc12
# COC(=O)c1ccc2ccc(CC[S+]([O-])Cc3cccc(C(C)C)c3)cc2c1
# CNC(=O)CCSCc1ccccc1O
#
# 81.2% valid SMILES
# -------3400--------
# Cc1ccc2nc(SCC(=O)Nc3ccc(Cl)cn3)c(F)cc2c1
# Cn1cccc(-c2cc(F)cc3[nH]c(=O)c(-c4cnccn4)cc23)c1
# Cc1nnc2sc(CN(C)C)c(C#N)c(C)c2c1-c1cccc(Br)c1
# COc1ccc(C(Cn2cc([N+](=O)[O-])cc2CC)C(=O)NNc2ccccc2C)cc1
# Cc1c(Cc2ccccc2)c2c(Cl)cc(F)cc2n1C1OC(CO)C(O)C1O
#
# 82.8% valid SMILES
# -------3600--------
# Cc1n(-c2ccc(COc3ccccc3)cc2N)c(=O)n(-c2ccccc2)n1
# CCOC(=O)C1CSC=C(C(=O)OCC)N1C(=O)C1CC(=O)N(c2ccccc2)C1
# C#Cc1ccc(S(=O)(=O)NC(Cc2ccccc2)C(N)=O)cc1
# CCN(CC)C(=O)Cn1c(=S)sc2cc(S(=O)(=O)N3CCOCC3)ccc21
# Cc1ccc(S(=O)(=O)N(C)c2cnc(N)nc2C(F)(F)F)cc1
#
# 81.2% valid SMILES
# -------3800--------
# CCCOCCOCCOC(C)=O
# O=C(c1cccnc1)N1CCC2(CC1)CN(c1ncccn1)C2
# O=C1NC(=O)C(c2ccc(Nc3ccc(Cl)cc3Cl)cc2)=NC1=O
# COc1ncccc1C(=O)N1N=CNC(c2ccccc2)CC1c1ccccc1OC
# O=C(c1cc(-c2ccoc2)nc2ccccc12)N1CCC1
#
# 82.0% valid SMILES
# -------4000--------
# COC(=O)c1ccccc1NC(=O)COC(=O)CN1C(=O)C(CC(=O)NCCO)NCC1=O
# COc1ccc(NS(=O)(=O)c2ccc(C(=O)c3cccc(F)c3)cc2)c(C(N)=O)c1
# c1ccc2[nH]c3sc(-c4ccc(Nc5nc6ccc(-c7cnc7ccc(C76CCNCC(7)6)cc54)c4)ccc3s2)c1
# COc1ccc2c(c1)CC(C(O)c1ccc3sc4ccccc4c3c1)N2C
# Cc1nc(Nc2nc(-c3cc(C)cc(-c4ccccc4)c3)cnc2C)c[nH]1
#
# 79.7% valid SMILES
# -------4200--------
# Sc1nc2ccc3ccccc3c2nc1-c1ccccc1
# O=C(NCc1ccccc1)c1ccc2nc(N)c(-c3ccccc3Cl)nc2c1
# COC(=O)CCc1cc(OC)c(OC)c(OC(F)(F)F)c1
# CNC(=O)c1cc(S(=O)(=O)Nc2ccc3nc(C)cc(C)c3c2)ccc1-n1cnc(C)c1
# CN(CC(=O)Nc1nc2c(sc3c(c12)CCC3)C(C)C
#
# 78.9% valid SMILES
# -------4400--------
# O=C(Nc1cccnc1)n1c(NC(=O)CN2CCC(C(=O)Nc3ccc(Cl)cc3)CC2)cc(CC=C(C)C)c2ccccc21
# CSc1nc2c(c(=O)[nH]c3ccc(C)cc23)n1C
# O=C1OCC2C1OC1(c3cccs3)OC(=O)CC2O1
# CCCc1ncnc(NCc2ccc(OC)n([N+](=O)OC)c2=O)c1C
# Cc1ccc(NC(=O)CC(NS(C)(=O)=O)Nc2ccccc2)cc1
#
# 80.1% valid SMILES
# -------4600--------
# COc1cc(C=NN2CCN(C3Cc4ccccc4Cc4cc(OC)c(OC)cc43)CC2=O)ccc1O
# N=c1sc(N2CCOCC2)nn1CC(C)(C)c1nccs1
# O=C(CCS(=O)(=O)Cc1ccc(F)cc1)N1CCN(c2ccccc2)CC1
# COC(=O)c1cc2nc(-c3ccc(C(C)C)cc3)oc2cc1OC
# CC1=C(c2cc3ccccc3c3ccccc23)CCC1(C)N
#
# 84.8% valid SMILES
#   0%|          | 0/4607 [00:00<?, ?it/s]
# -------200--------
# CCOc1ccc(CCNCC(O)COc2ccccc2OC)cc1
# Cc1ccc(-c2nnc(O)c3c2C(C)OC3(C)C)cc1
# O=C1C2CC(OC3OC(CO)C(O)C(O)C3O)C3OC(C)(C)OC3C2C(C)(O)C12
# NC(CCC(=O)NO)C(=O)Nc1cccc(CNS(=O)(=O)c2ccc(C(N)=NO)cc2)c1
# CC(C)NC(=O)C(=O)Nc1cccnc1
#
# 82.8% valid SMILES
# -------400--------
# COc1cc(F)c(N(C)CCCN2CCN(S(C)(=O)=O)CC2)cc1C(=O)c1ccccc1
# CCN(CC)C(=O)Cn1nc(Oc2ccccc2)c2ccccc2c1=O
# O=[N+]([O-])c1ccccc1CNc1ccc(Cn2cccc2)cc1Br
# Cc1cccc(-n2cnc(-c3ccccc3)c2C=CC(=O)c2ccccc2[N+](=O)[O-])c1
# Cc1ccc(-c2nc3ccccc3[nH]2)cc1
#
# 84.4% valid SMILES
# -------600--------
# CC(N=C(S)Nc1ccc(CCN2CCOCC2)cc1)c1cc(C(F)(F)F)cc(C(F)(F)F)c1
# CCOCCCNC(=O)CNC(=O)NCC1CNc2c(O)nc(C)nc2O1
# Cc1ccccc1N1CCN(C(=O)CN2c3ccccc3C(=O)N2C)C(c2ccc(OCC(=O)O)cc2)C1
# O=C(CC(c1ccccc1)c1ccccc1)Nc1ccc(C(F)(F)F)cc1
# COCOc1ccc(-c2cc3cc(O)ccc3[nH]2)cc1
#
# 85.2% valid SMILES
# -------800--------
# COc1cccc(C2C3Cc4ccc(OC)cc4C32CC(C)(O)CC2(O)C#N)c1
# CC(Nc1cc(NCCCO)nc(-c2cccnc2)n1)C1CCC(C)CC1
# CCCc1cc2nc(N)nc(N)c2nc1C=CC=C(C)C
# COc1cc(-c2nc(CSCCc3ccccc3)c(C)o2)cc(OC)c1OC
# Cc1cccc(OCCOc2no[n+]([O-])c2-c2ccccc2)c1
#
# 84.4% valid SMILES
# -------1000--------
# Cc1ccccc1NC(=O)CN(C(=O)C1CNC(=O)O1)c1ccc(C(N)=O)cc1
# CC(c1ccccn1)N1CC2C(Oc3ccccc3)CCN1C2=O
# CC(C)c1ccc(NC(=O)CCS(=O)(=O)c2cc(Cl)c3c(c2)OCCC3(C)C)cc1
# Cc1cccc(NCC(=O)N2C(=O)c3ccccc3C2=O)c1
# O=C(C=Cc1ccc(O)cc1)c1c(O)cc(O)c(-c2ccoc2)c1O
#
# 84.0% valid SMILES
# -------1200--------
# O=C(Nc1ccccc1Cl)c1ccc2c(c1)C(NS(=O)(=O)c1ccccc1)C(=O)O2
# COc1ccc2c(Nc3ncc(C)c(C)n3)cc[n+](C)c2c1
# CN1CCN(CCN2CCn(S(=O)(=O)c3ccccn3)CC2)CC1
# COc1cc2ccccc2cc1-c1ccncc1
# C=CCn1c([N+](=O)[O-])cnc1C(=O)c1c[nH]c2ccccc12
#
# 87.5% valid SMILES
# -------1400--------
# Nc1ccc(-c2ccc(NCc3ccnc(Nc4ccc(N5CCC(N)CC5)nc4)c3)cc2)cc1C(F)(F)F
# CCC(C)ON=C(N)c1cccc(C(=O)O)c1
# Cn1ccnc1CN1CCN(c2nc3cc(F)ccc3n3cccc23)CC1
# Cc1ccc2nc(C=Cc3ccc(Cl)cc3)oc2c1
# CN(C)S(=O)(=O)Nc1ccc(CC(=O)NCCCO)c(Cc2ccc(Nc3nccc(Nc4ccccc4C(=O)O)c3C#N)cc2)n1
#
# 85.2% valid SMILES
# -------1600--------
# COC(=O)C1=C(C)N(c2cc(OC)ccc2OC)CN2CC1CC2
# COc1ccccc1CCn1c(C)ncc1-c1ccc(O)cc1
# Cc1nc2ccccc2c(=O)n1-c1nc2ccccc2[nH]c1=O
# N#Cc1nc(-c2cccc(C(=O)NC3CCNCC3)c2)c2c(O)cccc2n1
# COc1ccc(-c2nc3cc(C)ccn3c2Nc2ccccc2Cl)cc1
#
# 85.2% valid SMILES
# -------1800--------
# CC(=O)Nc1ccc(C(=O)O)c(Nc2nc3ccccc3nc2S(=O)(=O)c2ccc(C)cc2)c1
# CNc1ccnc(NC(=O)Nc2cc(C(C)(C)C)cc(C(F)(F)F)c2)c1
# CC(=O)N(c1nc2ccccc2s1)C1CCOc2nnc(C3CC3)n2C1
# C=CCNC(=S)NN=Cc1cc(Br)ccc1OC
# O=C(C=Cc1ncnc2c(C(=O)c3cccnc3)cnn12)NCc1ccc(Br)cc1
#
# 76.2% valid SMILES
# -------2000--------
# O=C1NC(=O)C(=Cc2ccc(OCc3ccccc3)cc2)C(=O)N1
# O=C(NC1CCc2ccccc21)c1cccs1
# COc1cnc(C2CC(=O)N(c3cccc(C(C)C)c3)C2)c(OC)c1
# CC(C)NC(=O)C12CCC1C(N1C(=O)C1C(CO)Cc1ccccc1-2
# C=CC1CN2CCC1CN(S(=O)(=O)c1ccc(C)cc1)C2
#
# 85.2% valid SMILES
# -------2200--------
# CC1(C)CN2CCN(c3ccccc3)CC2N=C1N
# COc1cc2nc(N(CC(C)C)Cc3nccs3)nc(C(F)(F)F)c2cc1OC
# COCN(c1ccc([N+](=O)[O-])c(C)c1)S(=O)(=O)c1ccccc1
# CC1=C(SC(=O)c2ccc(C#N)cc2C)CNCC1
# Cc1nn(-c2ccc(Cl)cc2)cc1C1CCCN(C(=O)CCO)C1
#
# 78.9% valid SMILES
# -------2400--------
# O=C(Oc1ccc(C=Nc2cccc(C(F)(F)F)c2)cc1)C1=C(O)c2ccccc2S(=O)(=O)N1
# NS(=O)(=O)c1ccc2c(c1)Oc1ccc(Br)cc1CC2
# NCc1ccccc1-c1nc2ccccc2c(=O)[nH]1
# O=C(NCCN1C(=O)C2CCCN2c2ccccc21)c1ccc(F)cc1
# COc1ccc(NC2=NCCn3c2nc(C)cc3c4cc(Cl)ccc42)cc1OC
#
# 85.5% valid SMILES
# -------2600--------
# CC(O)c1cc(C(=O)O)nc(CC(C)(C)O)n1
# Cc1ccc(NS(=O)(=O)c2ccsc2C(=O)Nc2ccc(C)c(F)c2)nc1
# COC(=O)c1sc(C)[n+]([O-])c1SCc1ccccc1C)c1ccc(C)cc1
# O=c1cc(-c2ccc(O)cc2)oc2cc(O)c(O)cc12
# CC1(C#N)CCC2(C)C1CCC1(C)C(O)CCC21C
#
# 84.4% valid SMILES
# -------2800--------
# Clc1ccc(N=Nc2ccc(Cl)cc2Cl)cc1
# COc1ccc2cc(-c3ccccc3)c(-c3ccc(O)cc3)nc2c1OC
# CC(C)CNC(=O)c1noc(-c2ccccc2)c1N
# CN(C)c1ccc(C2CCNCC2)cc1
# Cc1ccc(CN2C(=O)N3C(Cc4c([nH]c5ccccc45)[N+](=O)[O-])-n3c2nc2ccccc23)cc1
#
# 86.7% valid SMILES
# -------3000--------
# CC(C)N(Cc1nc(-c2ccccc2)cs1)c1ccccn1
# Cc1ccc(S(=O)(=O)NC(=O)C(CN)CC(=O)OC)cc1
# Cc1[nH]c2ccccc2c1-c1nc2cc(C(F)(F)F)ccc2n1Cc1ccco1
# Cc1cc(C)cc(COCC(O)C(C)O)c1
# CC(C)=CC=CCC(NC(=O)C(C)C)CC(=O)C=CC(=O)O
#
# 84.0% valid SMILES
# -------3200--------
# Cc1ccccc1CNC(=O)CCC(=O)Oc1ccccc1OC(F)F
# NC1=Nc2ccccc2NC(c2cn(-c3ccccc3)nc2-c2ccccc2)C1
# CC=CC(=O)C1C(OC)C2(CCC(C)C(C=C)C(C)c3ccc(Br)cc3)CC1=O)C=Cc1cc(OC)c(OC)cc12
# CC(=O)Nc1cnc(-c2ccc(Oc3ccc(C)cc3)cc2)nc1C
# CCOC(=O)c1cccc(NC(=O)Nc2ccccc2Cl)c1
#
# 85.9% valid SMILES
# -------3400--------
# Cc1ccc(-c2nc(-c3ccc(C(=O)NCc4ccco4)o3)cs2)cc1
# CCN1C(=O)c2ccccc2Sc2ccc(C(=O)N3CC4CC3COc4ccc(Br)cc34)cc12
# COc1ccc(CC(NC(=O)C(=O)(C2OC(=O)C3C4OC=CC=CC=CC(O)C(O)C4O)C(O)C(OC)C23)cc1
# CC(C)c1ccc(NC(=O)CSc2snnc2N)cc1
# C=C(C)C1CC(C=CC(=O)O)CC(O)C1CC(=O)OC
#
# 85.5% valid SMILES
# -------3600--------
# COc1ccc(C=C(C#N)C=NNC(=O)c2cccnc2)cc1
# Cc1ccc(S(=O)(=O)Nc2nnc(-c3ccc(F)cc3F)o2)cc1
# COc1cc(CNc2ncccc2C(N)=O)c(OC)n1
# COC(=O)C1=C(c2ccc(OC)cc2)CC2CCC1N2CC
# COCCN(C)c1nc(C)c2cc3ccccc3nc12
#
# 87.1% valid SMILES
# -------3800--------
# CCc1nc2ccc(C(=O)Nc3ccc(N4CCCN(C)CC4)cc3)cn2c1N(C)C(=O)c1ccccc1[N+](=O)[O-]
# CS(=O)(=O)c1ccc(C2=C(c3ccccc3)CCC(N3CCN(C)CC3)C2)cc1
# Nc1cnc(-c2cccc(COc3cc(O)c(C(=O)NCCCc4c[nH]cn4)c3)c2)cn1
# COc1ccc(-c2cc(C(=O)Nc3ccc(C)cc3F)ccc2C2CCN(C(C)CCc3ccccc3)CC2)cc1
# Nc1ccc2[nH]c(-c3ccc(C(=O)Nc4ccc(Cl)c(NC(=O)NC4CCC(=O)O5)n4)cc3)nc2c1
#
# 87.5% valid SMILES
# -------4000--------
# CNC1CC2CCC(NCc3ccncc3)C2C1
# N#CC1=C(N)Oc2cc(S(N)(=O)=O)sc21
# CC(C)C(C(=O)NO)C1CCc2ccccc2C1
# COc1cc2c3c(cccc3c(=O)n2C)N(C(=O)Nc2cc(F)ccc2F)c2ccccc12
# COc1ccc(C2=Nc3cccc(OC)c3CC2c2ccccc2)cc1OC
#
# 83.6% valid SMILES
# -------4200--------
# COc1ccccc1NC(=O)Cn1nc(C)c([N+](=O)[O-])c1C
# COC(=O)C(C#N)=Cc1cn(CC2CCCN(c3ncccn3)C2=O)nn1
# CC(C)Oc1cc(NCc2ccc(Cl)c(Cl)c2)c([N+](=O)[O-])cn1
# O=S(=O)(n1cnc2cnc(N3CCNCC3)cc21)Nc1ccc2ncnc-2c2ccccc12
# C[n+]1nc2c(c(C(=O)O)c1CO)CCC2
#
# 89.5% valid SMILES
# -------4400--------
# CC(NCCc1ccccc1)C1CCC(CC(Cc2ccccc2)Oc2ccccc2)CC1
# CCOC(=O)C1=COC2OC3=C(C)OC(=O)C(CC(=O)c4ccc(OC)cc4)CCC3(C)CCC2C2(C)C(O)C(C(=C)C)C21
# Cc1cccc(Sc2cccc(CN3CCOCC3)c2)c1
# Cc1cccc(NC(=O)CN2C(=O)NCC3c4ccccc4C3C2=O)c1C
# Cc1nc(CN2CCN(C(=O)c3ccc4c(c3)OCCO4)C(C)C2)cs1
#
# 88.3% valid SMILES
# -------4600--------
# Cc1cnc(NC(=O)CNC2CCC(C(C)(C)C)CC2)nc1Cl
# COc1ccc(Cn2c(=N)n(CCOc3ccccc3)c3nc(C#N)ccc32)cc1
# Cc1cc(C)n(CC(=O)Nc2cccc(S(C)(=O)=O)c2)n1
# COc1ccc2c(c1)C13CC4CC(CC(C)(O)C4)C3C1C2
# COc1ccc(S(=O)(=O)Nc2nnnn2-c2ccccc2)cc1
#
# 86.3% valid SMILES
#   0%|          | 0/4607 [00:00<?, ?it/s]
# -------200--------
# CCCc1cc(=O)oc2cc(OCC(=O)NC3CC3)ccc12
# Cc1cc(C)n(CC2CCC2)c1C
# N#Cc1cc(C(=O)c2ccnc3ccccc23)c(Cl)cc1F
# CCOC(=O)C(C)(C)NC(=O)c1ccccc1NC(=O)Cc1ccc(OC)cc1
# O=C(NC(=S)Nc1ccc(O)nc1)CC(c1ccccc1)c1ccccc1
#
# 87.9% valid SMILES
# -------400--------
# O=C(NN=Cc1ccc([N+](=O)[O-])s1)Nc1ccccc1C(F)(F)F
# COc1ccc(N2CCN(C(S)=Nc3ccc(Br)cc3)CC2)c(OC)c1
# Cc1cc(C)cc(N2CCN(c3ncnc4c(S(C)(=O)=O)cccc34)CC2)c1C
# CCOC(=O)C1(CC)CCN(Cc2ccc(Cl)s2)CC1
# O=C(Nc1nccs1)C(=O)c1ccc(Oc2cccc3cccnc23)nc1
#
# 84.8% valid SMILES
# -------600--------
# O=C(O)CCNCc1ccc2[nH]c(O)nc2c1
# O=c1[nH]c(=O)n(CCC#Cc2cccc3ccccc23)nc1-c1ccc2oc3ccccc3c2c1
# COc1ccc(Cn2ccccc2=NNC(=N)N)cc1
# COc1ccc(N2C(=N)c3ccccc3C2N)cc1
# C=CCON1C(=O)C(=Cc2ccc(OC(=O)c3cccc(Br)o3)cc2)C=C1O
#
# 87.1% valid SMILES
# -------800--------
# CC(C(=O)NCc1ccco1)=NOC(C)CBr
# CCS(=O)(=O)NC1CC2CN(C(=O)c3cccc(F)c3)CC2N(C(=O)NCc2ccccc2)C1
# Cn1nnc(CNC(=O)c2ccoc2Cn2cnnn2)n1
# CCc1cc(-c2cc(C)c3onc(-c4cnn(CC(=O)NCC)c4)c3c2)cc(N(C)Cc2ccc3ccnn3c2)n1
# CC(=O)N1CCCn2nc(CN3CCN(C(C)=O)CC3)nc21
#
# 84.4% valid SMILES
# -------1000--------
# O=C(O)c1ccnn1-c1ccccc1
# O=C1C=CC(O)C2(Cc3ccc(CCN4CCOCC4)nn3)CN(CCCNC(=O)c3ccc4ccccc4c3)CC21
# CCCN(Cc1cc(-c2ccccc2F)no1)C1CC(c2ncnn2C)CC1
# Clc1ccc(-c2csc3c2[nH]c2ccccc23)cc1
# COc1ccc2nc(C)cc(Nc3ccc(C#N)cc3)c2c1
#
# 89.5% valid SMILES
# -------1200--------
# Cc1ccc(NC(=O)CSCC(=O)Nc2ccc3c(c2)OCCO3)cc1
# Cc1ccc(C(c2ccc(-c3ccc(CN(C)C)cc3)cc2)n2nccc2N)c1
# NN(c1ccc(Sc2ccc(Br)c[n+]2)cc1)C1CCS(=O)(=O)C1
# COc1cccnc1NC(=S)NCCCNc1cc(=O)oc2ccccc12
# COc1cc(OC)cc(C2C(C(=O)Cc3ccccc3)=C(O)C(=O)N2c2cccc(C(C)=O)c2)c1
#
# 86.3% valid SMILES
# -------1400--------
# CCOC(=O)CCN1C(=O)C(O)C(c2ccccc2)(c2ccccc2)C1C
# COc1ccccc1CNc1nc(-c2cc(C)nc(N3CCN(C(C)(C)C)CC3)n2)sc1C
# CC(C)C(N)c1nnc(C(C(=O)NCCCc2cnc[nH]2)C(=O)NC(CO)Cc2ccccc2)[nH]1
# Cc1c(Cc2ccc(F)cc2)c(O)nc2c(Cl)cc(Cl)cc12
# O=C1NC(Cc2cc3ccccc3cc3ccccc23)C(=O)N1C1CCN(CC2CS(=O)(=O)c3ccccc32)CC1
#
# 85.9% valid SMILES
# -------1600--------
# CCNC(=O)N1CCN(C(=O)N(CCC)CC(Cn2cnc3ccc(N(C)C)cc32)C(C)C)CC1=O
# COC(=O)c1c(C(C)=O)c(=O)n(CC(=O)c2ccc(Cl)cc2)c2nc3ccccc3nc12
# Cc1cc(OCc2ccccc2)cc(C(F)(F)F)c1C=C(C#N)c1nc2ccccc2nc1C
# O=C(O)c1cn(COCCOCN2CC3CC3c3ccccn3)C2)cn1
# CN(c1ccccc1)S(=O)(=O)c1cccc(C(=O)Nc2nnc(SCC(=O)Nc3ccc(F)cc3)s2)c1
#
# 85.2% valid SMILES
# -------1800--------
# O=C1Cc2cc(OCC(O)COC(=O)c3ccc([N+](=O)[O-])cc3)ccc2O1
# COC(=O)c1ccc(C(=C(CC(=O)O)N2C(=O)NC(c3ccccc3)c3ccccc32)c2csnn2)cc1
# ClC1Cc2cc(C3OC(CO)C(O)C(O)C3O)c3c(c2O1)CCS3
# C=CCc1cccc(C(C(=O)O)c2ccc3ccccc3c2)c1
# Cc1ncc2c(n1)CN(Cc1cnccc1-c1cnc(C(N)=O)[nH]1)CC2
#
# 81.2% valid SMILES
# -------2000--------
# CCCOCc1c(Cc2ccccc2)c(CO)n(Cc2ccc(C(=O)O)cc2)c1C
# O=C1CC(=O)N2C(Cc3c[nH]c4ccccc34)CN2C1=O
# CC(C)(C(=O)O)N(Cc1ccccc1)S(=O)(=O)c1ccc(Cl)cc1
# O=C(O)Cc1ccc(NC(=O)c2cccc3[nH]ccc23)c(F)c1
# COc1cc(-c2noc(-c3ccc(Cl)cc3)n2)cc(OC)c1OC(=O)c1ccc(Cn2cccn2)cc1
#
# 84.4% valid SMILES
# -------2200--------
# Cc1nc2c(CCCNS(=O)(=O)c3ccc(C=[N+](C)c4ccccc4)cc3)c[nH]c2cc1C
# Cc1cc(S(N)(=O)=O)ccc1-c1nc(-c2ccc(Cl)c(Cl)c2)c(-c2ccccc2)o1
# CCc1c(Sc2ccc(Nc3c(C(=O)O)cnc4cc(OC)c(OC)cc34)cc2)nc(C)nc1C
# O=C(Cn1cnc2ccccc2c1=O)N1CCC(F)(Cc2ccccc2)CC1
# Cc1sc2nc(CSc3nnc(NCCc4ccc(F)cc4)n3O)nc(O)c2c1C
#
# 89.8% valid SMILES
# -------2400--------
# CN(C)CCCn1c(=O)c2c3[nH]c(=S)[nH]c3c(Br)c(-c3cnc4cccc(Cl)c4c3)cc21
# C=CCOCC(Oc1ccc(C(C)(C)C)cc1)c1cc(C(F)(F)F)cc(C(F)(F)F)c1
# Cn1c(Cc2ccc(Br)cc2)nnc1SCC(=O)NN=Cc1ccc(C2CNCC2O)cc1
# Cn1c(=O)c2c(nc(-c3ccc(CO)cc3)n2C)n(C)c1=O
# c1ccc(C2=Nc3cc(F)ccc3SC2)cc1
#
# 87.5% valid SMILES
# -------2600--------
# Cc1cc2c(O)ccc(C(=O)N(C)CCCN(C)C)c2n1
# CCN(CC)C(=O)CSc1nnc(NC(=O)Cc2ccccc2-n2cnnn2)s1
# Cn1cc(-c2ccc3cc[nH]c3c2)c2c1C(=O)c1ccccc1C2=O
# CCSc1nnc2sc(=C3NC(=S)N=C(N)C3=O)N2CCc1ccccc1
# CS(=O)(=O)c1ccc2nc(-c3ccc(O)c(O)c3)sc2c1
#
# 87.1% valid SMILES
# -------2800--------
# Cc1cc(S(=O)(=O)N2CCOCC2)cc(CC)c1Oc1cc(Nc2ccc(Cc3cnc4ccccc4n3)cc2)c(C(N)=O)cc1NS(C)(=O)=O
# Cn1c(=O)[nH]c2cc(C(=O)c3cn4cccnc4n3)ccc21
# COc1cc(CN2CC(CO)c3ncccc3C2=O)cc(OC)c1OC
# Cc1ccc(C(O)C(NCc2cccnc2)c2ccccc2)cc1
# O=C(Nc1sc(-c2ccccc2)nc1-c1ccccc1)c1cccc(Br)c1
#
# 89.8% valid SMILES
# -------3000--------
# Cc1cccc(C)c1NC(=O)NCC(C=Cc1ccccc1)NC(=O)C1(C)CC(=O)N(C(C)C)C1=O
# O=[N+]([O-])c1ccccc1SSc1ccc([N+](=O)[O-])cc1[N+](=O)[O-]
# CCc1cc(C#N)cc2nc(-c3ccc(OC(F)(F)F)cc3)sc12
# O=C(ONC(=O)c1cccnc1)c1cc(F)cc(F)c1
# CCc1ncnc(-c2ccc(C(=O)N3CCN(Cc4ccccc4)CC3)c(Cl)c2)c1C#Cc1ccc(N)nc1
#
# 86.7% valid SMILES
# -------3200--------
# O=C(NN=Cc1ccccc(O)c1)c1ccccc1
# CC(=O)c1cnc2c(Br)cc(Br)cc2c1N(C)C
# CC1(c2ccccc2)c2nc3ccccc3n2C1c1ccc(Cl)cc1
# O=[N+]([O-])c1ccc(C(=O)N=c2cc(-c3ccccc3)c(O)[nH]c2=S)cc1
# COc1ccccc1-c1cc2c([nH]1)C(=O)c1coc3c(C)ccc(C)c3c1C2=O
#
# 91.0% valid SMILES
# -------3400--------
# O=C1c2nc(-c3ccccc3)cc(O)c2CC(c2ccccc2)OC12CCN(C(=O)c1ccc(-c3ccccc3)cc1)CC2
# CC1(C)OC(=Cc2ccc([N+](=O)[O-])o2)C(=O)OC1=O
# CC(=O)Nc1ccc(Cc2ccc3c(c2)C2(COC(N)=N2)C2(COC2)C2(CCC(O)CC2)O3)cc1
# O=C(NC1C(OCc2cccc(F)c2)C(O)C(O)C1O)c1ccc(Cl)cc1
# c1ccncc1-c1ncn2ccccc12
#
# 89.5% valid SMILES
# -------3600--------
# CCN(C(=O)COC(=O)CCc1nc(O)c2ccccc2n1)C1CCS(=O)(=O)C1
# CCOC(=O)c1ccc(NC(=O)Nc2cccc(-c3nc4cccc(OC)c4o3)c2)cc1
# O=C(Nc1cnccc1Cl)C1CC=CCC1C(=O)O
# c1ccc(-c2ccc3nnc4c(c3n2)n2ncnc2-4)cc1
# O=C(NCCCNc1nc(Nc2ccc3c(c2)OCO3)nc(N2CCOCC2)n1)Nc1ccc2c(c1)OCO2
#
# 87.9% valid SMILES
# -------3800--------
# Nn1c(SCC(=O)N2CC(=O)Nc3ccccc32)nc2ccccc2c1=O
# CN1C(=O)C(NC(=O)Nc2ccccc2F)N(C)C1=S
# CC1C(N)CN1c1c(F)c(N)n2c(-c3c(C)cc(C#N)c(NC4CCC4)c3)nc(OC3CC3)c2c1F
# CC(C)(C)CSC(N)=[N+](C)[O-]
# O=C(CNc1ccc(N2CCNCC2)cc1)OCCCn1ccnc1
#
# 85.5% valid SMILES
# -------4000--------
# Cc1c(C(=O)N2CCn3c(nnc3Cc3ccccc3)C2)sc2nc(-c3cccs3)c(C)n12
# CN(Cc1ccc(F)cc1)CC(O)COc1ccc(F)cc1
# CS(=O)(=O)c1ccc(C2=C(c3cccn3-c3ccccc3)CC3(CC2)CNC(=O)C3)cc1
# CCc1nc2c(C)cc(C)nc2n1Cc1cccc(C(=O)NC(Cc2cc(F)cc(F)c2)C(O)C(O)C(=O)NC2CCS(=O)(=O)C2)c1
# N#Cc1ccc(-c2cc(C(=O)N=C(N)N)c3n2CCC3C(=O)O)cn1
#
# 90.6% valid SMILES
# -------4200--------
# C=C1CC(C)C(C=Cc2ccc(OC)cc2)=CC1=Cc1ccc(Oc2ccccc2C)cc1
# CCOC(=O)c1c(-c2ccccc2)n(CCO)c(C)cc1O
# C=CCN(c1cccs1)c1ccc2ccccc2n1
# Cc1cc(=O)c2c(C)c(O)c(OC3OC(CO)C(O)C(O)C3O)cc2o1
# O=C(CN1CCN(C2=NS(=O)(=O)c3ccccc32)CC1)Nc1ccc([N+](=O)[O-])cc1[N+](=O)[O-]
#
# 86.3% valid SMILES
# -------4400--------
# CC(=O)N(c1ccccc1)C1CC(=O)N(c2ccc3c(c2)OCCO3)C1=O
# Cc1cnc(C(=O)N(C)C2CCN(CC(=O)NC(C)c3ccccc3)CC2)c(Cl)c1
# CCOc1ccc(Sc2ccccc2NC(N)=O)cc1
# O=c1oc(-c2ccc(F)cc2)cs1
# COc1ccc(C2Cc3ccccc3-n3cncc3C2C(=O)NC2CC2)cc1
#
# 88.3% valid SMILES
# -------4600--------
# COc1ccc(C(=O)N(CCCc2ccccc2Cl)c2ccc(F)cc2)cc1
# CCOC(=O)c1c(NC(=O)COC(=O)C2CCOC2)sc2c1CC(C)(C)OC2
# CC1CN(C(=O)c2ccccc2C#N)CCN1c1cccc(-c2cccc(-c3nc4cc(F)ccc4o3)c2)c1
# CCN(CC)C(=O)C(NC(=O)CC1CCCN1C(=O)OC)C(C)=CC(=O)OC
# CN1CCC(N(c2cccc(-c3cc(-c4ccccc4C(F)(F)F)n[nH]3)C2)C1
#
# 93.0% valid SMILES
#   0%|          | 0/4607 [00:00<?, ?it/s]
# -------200--------
# O=C(Nc1cccc(OCCn2cccn2)c1)C1CCc2ccccc2C1
# COC(=O)c1ccc2c(c1)C(C)=CC(C)(C)N2
# O=C1NC(=O)C(=Cc2ccc(OCc3ccccc3Cl)cc2)C(=O)N1
# CC(C)C(=O)N1CCc2nc(COc3ccc(CC4COC(c5ccccc5)4CCO)cc3)sc2C1
# CC(C)(C)OC(=O)N1CC(CNCc2ccccn2)NCC1Cc1ccccc1
#
# 87.9% valid SMILES
# -------400--------
# N#Cc1c(-c2ccccc2)cn(-c2ccc(N)cc2)c(=O)c1Cl
# CSc1nc2ccccc2s1
# c1ccc(COC2C3CCC(C3)N2Cc2ccccc2F)cc1
# O=C1c2c(ccc(-c3ccccc3)n2)CC(c2ccc(O)cc2)N1c1ccc(-c2cc[n+]([O-])cc2)cc1
# C#CCOC(=O)Nc1cccc(-c2ccccn2)c1
#
# 86.7% valid SMILES
# -------600--------
# Oc1nc2ccccc2n1-c1nc(Nc2cc3c(cn2)[nH]c2ccccc23)n[nH]1
# CC(=O)Oc1cccc(NC(=O)c2ccc3c(c2)OCO3)c1
# c1ccc(Cc2nc3cccnc3nc2Cl)cc1
# COc1ccccc1N(CC(O)Cn1ccnc1)c1ccc(Cl)cc1
# Cn1nc(C(=O)c2ccco2)c2ccccc2c1=O
#
# 88.7% valid SMILES
# -------800--------
# CCCN(Cc1ccccc1)Cc1csc(Br)c1
# CN(C)C1CCc2ccc3[nH]cc(C(=O)c4ccc5ccccc5c4)c3c2C1
# CC(C)(C)OC(=O)N1CSCC1C(=O)NC(COCc1ccccc1)C(=O)O
# CCN(CC)CCNC(=O)C1CCN(c2cc3c(cc2Cl)NC(=O)C(=Cc2cccn2C)N(C(=O)Nc2cc(C)ccc2Cl)C(C)C1=O)C(C)C
# CON=C(C#N)C(=O)NC1C(C)OC(COC(C)=O)OC1C(O)CO
#
# 90.2% valid SMILES
# -------1000--------
# c1cncc(CNCc2cc(-c3ccc(-c4cccc(NCCO)c4)cc3)on2)c1
# O=C(Nc1cc(-c2ccccc2)no1)c1ccc(Cl)cc1
# CC1C2Cc3ccc(C(=O)O)cc3C1(C)CCN2CC1CC1
# S=C(Nc1ccc(-c2ccc(C(F)(F)F)cc2)o1)N(CCO)CCO
# CC(Cn1cccn1)Cc1nc(C)c(C)n1-c1ccccc1
#
# 89.1% valid SMILES
# -------1200--------
# C=CCNC(=O)NCCc1ccc(OC)c(OC)c1
# CCn1c(NCc2ccc(O)c(O)c2)nc2ccccc21
# COc1cc(C)c(CC(=O)NNC(=O)c2ccncc2)cc1OC
# COc1cccc(C(=O)Nc2c(C(N)=O)nn3ccc(C)cc23)c1OC
# COc1cc2c(cc1O)C(=O)OC(C)CC2
#
# 90.6% valid SMILES
# -------1400--------
# CC(C)=CCC(OCCn1c(Sc2cc(C(=O)O)cc(=O)n2C)c2cc(O)ccc2n1C)c1ccccc1
# CC1C2Cc3ccc(O)cc3C1(C)CCN(C)C2
# COc1ccc2c3c(n(C)c2c1)C(CO)N(Cc1ccccc1F)C3c1cc(OC)cc(OC)c1
# COC(=O)n1c(SCCN(C)C)c(C(=O)OCC)c2cnc(C#N)n21
# COC(=O)CN1C(=O)SC(=Cc2cccc3ccc(Cl)cc23)C1=O
#
# 89.8% valid SMILES
# -------1600--------
# O=C(Nc1ccc(CO)cc1)Nc1cccc(Cl)c1
# CSc1cc(F)ccc1Oc1cc(C)nc2ccccc12
# O=C(Cn1cnc2ccccc2c1=O)NCCCOCC(F)(F)F
# O=C(NCCO)c1ccc(-n2cccc2)cc1
# CS(=O)(=O)c1ccc(Cl)c2c(N)c(C(=O)NC3CC4CCC3C3)oc12
#
# 90.6% valid SMILES
# -------1800--------
# Cc1cc(O)cc2nc(-c3cc(-c4ccc(CO)o4)c(Br)c(O)c3O)[nH]c12
# Cc1nn(C)c2c1C(C)N(C(=O)Nc1ccc(Cl)cc1)C2
# COc1ccc(C2CCN(S(=O)(=O)CC3CC3)CC2)cc1
# CN1CCC(CC(c2ccc(-c3ccccc3)cc2)c2ccccc2)CC1
# CCOC(=O)c1c(CC)c2c(=O)n(C)c3ccccc3n2c1-c1cccc2ccccc12
#
# 91.0% valid SMILES
# -------2000--------
# CCCOC1=C(C(=O)OC)C(c2ccccc2NC(=O)c2ccccc2)SC1
# Cc1cc(C(c2ccc(C)cc2Cl)N2CCC3(CCN(Cc4ccncc4)C3)C2)ccc1F
# O=C(NN=Cc1c(O)ccc2ccccc12)c1cccc2ccccc12
# Cc1c2c3ccccc3nc-2cn1Cc1ccc(Cl)nc1
# COc1ccc(CCNC(=O)C2CC(=O)N(c3ccc4c(c2)OCO4)C3)cc1OC
#
# 86.3% valid SMILES
# -------2200--------
# Nc1ncc(-c2ccc(Cc3cn4cc(-c5ccncc5)sc4n3)cc2)nc1O
# O=C(c1ccco1)Oc1cccc2c1CCC(Nc1ncccn1)C2
# N#CC(c1ccccc1)N1CCN(C2CCC2)CC1
# C=CCn1c(=O)c(C2C3CC4CC(C3)CC2C4)ccc2c1OC(CF)CC2
# Cc1ccc(S(=O)(=O)N(C)CC(=O)N2CCN(C(=O)c3ccco3)CC2)cc1[N+](=O)[O-]
#
# 87.1% valid SMILES
# -------2400--------
# CC(=O)C1C(C)CC2(O)CC=C(C)CCC3(CC2)OCC(OC(=O)C=C(C)C(=O)OCC2CC3)C21
# CC(C)c1cc2c(cc1OS(N)(=O)=O)CCC1C2CCC2(C)C(=O)CCC12
# CCCOCCNC(=O)C(Cc1ccncc1)NC(C)=O
# CCCN(C(=O)Cc1cccs1)c1nc(-c2cc(C(C)(C)C)cc(C(F)(F)F)c2)no1
# CCc1ccc(NC(S)=NC)cc1
#
# 90.2% valid SMILES
# -------2600--------
# COc1ccc(Cc2nnc(SCC(=O)NC(C)C)[nH]2)cc1
# CCCc1c(OCCCN(C)C(C)C(O)c2ccc(F)c(CN(C)C)c2)ccc2[nH]cnc12
# Cc1ccc2nsnc2c1Nc1ccccc1[N+](=O)[O-]
# CCc1cnc(C)nc1Oc1ccc(C(=O)NCC2CCN(C)CC2)cn1
# O=[N+]([O-])c1ccc2nc(NC3CCCOC3)nc(-c3ccccn3)c2c1
#
# 93.0% valid SMILES
# -------2800--------
# CCCNCCCOc1ccccc1C(C)NC(=O)Nc1ccccc1
# CNC(=O)c1ccc(-n2c(C3COc4cc(OC)ccc4OC3)nc3ccccc32)cc1
# N#Cc1nc(CN2CCN(C(=O)c3ccc(Cl)cc3)CC2)n2c1CCNCC2
# COc1ccccc1-c1c(C)c(=O)[nH]c(=O)n1CCO
# COc1ccc(C)c(N2CCCN(C(=O)CN3C(=O)c4ccccc4C3=O)CC2)c1
#
# 92.2% valid SMILES
# -------3000--------
# N=C(N)Nc1ccccc1-c1ccc(C(=O)Nc2ccc(C(=N)N)cc2)cc1
# CCCn1nc(-c2ccc(Cl)cc2)c2c1C(C)(C)CCC21CCC(OC)CC1
# COc1cc(CSc2nnc(C=Cc3ccc4c(c3)OCO4)n2C)cc(OC)c1OC
# O=C(Cc1ccc2cc(OCCc3nc4ccccc4[nH]3)ccc2c1)NCCCN1CCOCC1
# Clc1ncc(Cl)cc1C1CCNCC1
#
# 91.4% valid SMILES
# -------3200--------
# CC(C)(C)n1cc(C(=O)O)c(=O)n(Cc2ccc3ccc(COC(=N)N)cc3c2)c1=O
# CN(Cc1coc(-c2ccc(F)cc2)n1)c1ccc(NS(C)(=O)=O)cc1
# CC1N(C(=O)c2ccc(F)cc2)CC1c1ccccc1OCC(=O)O
# Cc1ccc(C=C2SC(=S)N(C3CCOCC3)C2=O)cc1
# CCOc1ccc(OCC)c(Nc2cc(F)cc(C3CCNCC3)c2)c1
#
# 88.3% valid SMILES
# -------3400--------
# Cn1cc(S(=O)(=O)c2cccc(C(=O)Nc3c(C(=O)c4ccco4)cccc3C(F)(F)F)c2)cn1
# N#Cc1ccc(CC(c2c[nH]c3cc(NC(=O)c4cncn5cccc5c4=O)[nH]c23)cc1
# Cc1cccc(OCc2nnc(NNC(=O)c3ccncc3)s2)c1
# CCOc1ccc(NC(=O)Cn2c(=O)n(C)c3cc(S(=O)(=O)N(C)c4ccccc4)ccc32)cc1OCC
# O=C(O)CNc1ccc2c3c([n+](CC(=O)O)c(=O)c-2c1[O-])OCO3
#
# 91.4% valid SMILES
# -------3600--------
# COCC1OC(OC2C(n3cnc4c(NC)ncnc43)C(O)C2O)C(N)C(O)C1O
# COC(=O)CN1C(=O)C(CCCNC(=N)N)NC(c2ccccc2F)S1(=O)=O
# O=C(NCC(O)CO)c1nc(-c2cccc(Cl)c2)c(-c2ccncc2)[nH]1
# O=C(COc1ccc2cccnc2c1)NN=Cc1cccnc1
# N=C(N)N1CCC(CCN(c2ccc([N+](=O)[O-])cc2[N+](=O)[O-])S(=O)(=O)c2ccccc2)CC1
#
# 88.7% valid SMILES
# -------3800--------
# CON=C1C2C3CC(C)(C)C3CCC12C
# C=Cc1c(Cc2c(F)cccc2Cl)c(OC2OC(CO)C(O)C(O)C2O)c2nc3c(c(C)c3c(O)c2c1O
# OC(CNCCNc1ccnc2cc(Cl)ccc12)c1ccc(OC(F)(F)F)cc1
# CCOC(=O)c1ccc(NC(=O)C(NC(=O)c2cc(O)c(O)c(O)c2O)C(C)C)s1
# COc1ccccc1CNC(=S)NN=Cc1cc(Br)cc(Br)c1O
#
# 92.6% valid SMILES
# -------4000--------
# CCc1nn2c(=O)cc(COC(=O)CSCCNS(=O)(=O)c3ccc(F)cc3)nc2s1
# CCC(CC)Nc1oc2ccccc2c(=O)c1-c1ccccc1
# N#CCC(=O)Nc1cccc(-c2ccc(-c3ccc(CC(NC(=O)c4ccccc4)C(O)C(=O)O)cc3)cc2)c1
# COc1ccc(C(=O)NCCC(=O)NCCc2ccco2)cc1
# O=C1c2ccc(-c3ccccc3)cc2OCc2nccc(c21)c1ccnn1CC#CCN1CCOCC1
#
# 86.3% valid SMILES
# -------4200--------
# CN(c1cccnc1)n1ccc2ccc3c(c21)CCC1C3Cc2ccccc21
# O=C(CN1CC[S+]([O-])Cc2ccccc21)NS(=O)(=O)c1ccc(NS(=O)(=O)c2ccccc2)cc1
# O=C(Nc1ccc(N=C(S)Nc2ccc(Br)cc2)cc1)C1CC1
# N#Cc1ccccc1NC(=O)c1ccc(CNC(=O)c2ccccc2NC(=O)c2ccc(Cl)cc2)s1
# Cc1c(CC(=O)O)cccc1COc1ccc2c(C)c(C)c(=O)oc2c1
#
# 94.9% valid SMILES
# -------4400--------
# COc1ccc(NC(=O)COC(=O)C2CCOCC2)cc1O
# O=C(Nc1ccc(S(=O)(=O)Nc2ccccn2)cc1)c1ccco1
# COc1ccc(CCNc2nnnn2-c2ccc3c(c2)OCO3)c(OC)c1Cl
# COc1cccc(NC(=O)COc2c(C(C)C)cccc2C(C)C)c1
# Fc1cccc(C2=Nn3c(nnc3-c3cccs3)SC2)c1
#
# 93.0% valid SMILES
# -------4600--------
# COc1ccc(-c2ccc3[nH]cc(Cc4ccc(N5CCOCC5)nc4)c3c2)cc1
# CCc1nnc(C2CCCN(S(C)(=O)=O)C2)o1
# Cc1ccc(S(=O)(=O)C(=Cc2ccc(-S(=O)(=O)O)cc2)C(=O)c2ccc3ccccc3c2)cc1
# CC(=O)N1CCN(C(=O)C=Cc2ccccc2)C(CN2CCC(N3C(=O)CC3)CC2)C1
# CCOc1ccc(-c2nc(N)nc(C)c2-c2cccc(CO)c2)cc1
#
# 93.4% valid SMILES
#   0%|          | 0/4607 [00:00<?, ?it/s]
# -------200--------
# O=C(O)C1=C(C(=O)Nc2ccc(-c3ccccc3S(=O)(=O)NC(=O)c3ccc(Cl)cc3)cc2)C(c2ccc(Cl)cc2Cl)NC(=O)N1
# Cc1cc2n[nH]c(=O)n2c2cnn(-c3ccccc3)c12
# NC1CCN(Cc2coc(-c3nonc3S(N)(=O)=O)n2)CC1
# O=C(Nc1cccc(-c2ccc3nnc(C4CCC4)n3c2)c1)c1ccncc1
# CCC1CCc2cc(F)cc(C(=O)NCCC(C)C)c2C1
#
# 92.6% valid SMILES
# -------400--------
# CC[N+](CC)(CC)CC(CN(C)C)[NH+](C)CCCc1ccccc1
# Cc1ccc(C(=O)CSc2nnc(NC(=O)Nc3ccc(C)cc3C)s2)cc1
# O=C(O)C(OCCO)=C1C(=O)NN=C1SCC(=O)N1c1ccccc1[N+](=O)[O-]
# CC(C)(C)c1cc(NC(=O)N2CCOCC2)ccc1-c1nnc(-c2ccccc2-c2ccc(Cl)cc2)o1
# CSc1ccc(CC(=O)N2CC(=O)Nc3ccccc32)cc1
#
# 91.0% valid SMILES
# -------600--------
# CCOC(=O)C1CCCN(C(=S)SC)C1
# C=CCN1CC2CCC1C(C(=O)OC)(OC(=O)CC(C)O)C2
# Cc1nc2ccc(Cl)cc2c(-c2ccccc2)c1CN
# COc1ccc(CN2CCN(CCCn3cnc4ccccc43)CC2)cc1
# C=CCOc1ccc(C2C(C(=O)c3ccc4c(c3)CC(C)O4)=C(O)C(=O)N2CCN2CCOCC2)cc1Br
#
# 93.0% valid SMILES
# -------800--------
# Cc1[nH]c2ncn(C)c(=O)c2c1C(=O)C(=O)NNC(=O)c1ccccc1
# Cc1n[nH]c(C)c1SC1=C(C(=O)O)N2C(=O)C(C(C)O)C2S1
# CCC1C(=O)N(Cc2ccc(C)o2)C2CCCN(Cc3ccccc3)C12
# COc1ccc(C=C(NC(=O)c2ccco2)C(=O)c2ccco2)cc1
# O=C(c1ccccc1)C(c1ccncc1)N(Cc1ccccc1)Cc1ccccc1
#
# 91.4% valid SMILES
# -------1000--------
# CC1=CC(=O)C2CC3OC3(C(=O)O)CCC(C)=C2C1O
# Cc1ccc(C(=O)CSc2nnc(CNC(=O)CC(N)C(=O)c3ccc(F)cc3)s2)c(F)c1
# CCOC(=O)C1CCCN(C(=O)CCc2nnc3n(CCCS(=O)(=O)c4ccc(Cl)c(Cl)c4)c4ccccc4nc23)CC1
# CC(=O)NC1CCN(CC(=O)NNC(=O)c2cc(-c3cccc(Br)c3)nc3ccccc23)CC1
# CN1CC(=O)N(c2c[nH]n(CCNC(=O)C(C)(C)C)c2=O)CC1
#
# 94.1% valid SMILES
# -------1200--------
# Cc1c(N2CCc3c([nH]c4ccc(C(=O)Nc5ccc(S(N)(=O)=O)cc5)cc34)C2=O)cccc1O
# Cn1c2ccccc2c2nnc(S)n21
# Cc1cc(C)n(CC(CS(C)(=O)=O)NC(=O)CN(C)C(=O)c2cc(C3CC3)[nH]n2)n1
# CC(C)(C)c1cc(NC(=O)Nc2ccc(CNC(=O)c3ccc(-c4cccnc4)cc3)cc2)no1
# CCC(=O)c1ccccc1OS(=O)(=O)CC(=O)NC(C(=O)c1ccc(Cl)cc1)C(C)C
#
# 90.2% valid SMILES
# -------1400--------
# O=S(=O)(Nc1ccc(CC(O)CO)cc1)c1ccc(F)cc1
# CCOC1CN2CCN(CC2)c2ccc3c(c21)C(C)=CC(C)(C)N3C(C)=O
# CCc1ncnc(C)c1CNCC1CC1c1cc(F)cc(F)c1
# C=CCn1c(CCC(=O)Nc2ccc(OC)cc2)nc2c3ccccc3ccc21
# Nc1nc(N)c2c(CN3CCc4c(sc(C(=O)Nc5cccc(F)c5)c4N3)cccc2n1
#
# 92.6% valid SMILES
# -------1600--------
# CC#CCN1C(=O)C(Cc2ccccc2)C(=O)N(c2ccc3c(c2)OCO3)C1C
# CN1CCCN(Cc2ccccc2)C2CCN(C(=O)c3ccccc3F)C12
# CC(C)CC1CNc2nc(N)[nH]c(=O)c2C1=O
# O=C(CCNC1=NS(=O)(=O)c2ccccc21)OCC(=O)c1cc(C(F)(F)F)cc(C(F)(F)F)c1
# COc1ccc2cc(C(C)C(=O)OCC(=O)c3cc(C)[nH]c3=O)ccc2c1OC
#
# 92.6% valid SMILES
# -------1800--------
# CCCc1ccccc1N1C(=O)C(O)(CC(=O)c2ccc(Cl)cc2)c2ccccc21
# CN(C(=O)C[S+]([O-])C(C)(C)C)c1nc(C#N)nc(N2CCOCC2)n1
# [N-]=[N+]=NC1CC(n2cnc3c(NC(=O)Nc4ccc(Cl)c(Cl)c4)ncnc32)OC1CO
# CCCN(CCC)C(=O)c1ccc(C(=C2CCN(CC=C(C)C)CC2)c2cccc(Cl)c2Cl)cc1
# CC(=NNC(=O)CCCN1C(=O)c2ccccc2C1=O)c1ccncc1
#
# 89.5% valid SMILES
# -------2000--------
# Cc1cc(C)c2cc(CONc3ccccc3)oc2c1
# N#CC1=C(OCc2ccccc2)c2ccccc2C2(O)CCCN12
# COc1c(CNCCO)ccc(-c2nc(C(N)=O)sc2N)c1
# C=CCSc1nnc(NNc2nc3ccccc3s2)nc1C(=O)c1ccc(Cl)cc1
# CC(C)C(CO)NCc1nc2cc(F)ccc2n1C
#
# 94.9% valid SMILES
# -------2200--------
# C=C(Br)CCC1(C)CC(OC(=O)NC(C)=CC(=O)c2ccccc2)C(C)(C)CCC1C(=O)OCC
# O=C(OC1Cc2c(O)cc(O)cc2OC1c1ccc(O)c(O)c1)C1CC(O)CO1
# CCCNc1nc(N(CCO)CCO)nc2c(Nc3cccc(Cl)c3C)nccc12
# O=C(Nc1ccccc1Br)Nc1cccc(OCc2ccccc2)c1
# Cc1cc(-c2nc3ccsc3c(Nc3cncc(Cl)c3F)n2)cc(NC(=O)CCC(=O)NCCO)c1C
#
# 95.3% valid SMILES
# -------2400--------
# CC(=O)NCCc1cc(O)c(O)c(O)c1
# C=C1CCC2C(C)(COC(=O)Nc3ccccc3)C(O)CCC2(C)C1C=C1Nc2ccccc2S(=O)(=O)N1S(=O)(=O)CO
# CCOc1cc(NC(=O)C2=C(O)C(=O)N(Cc3ccc(C)cc3)C2=O)ccc1O
# Cc1ccccc1S(=O)(=O)NC1CCc2cccnc2-n2c(CN(C)C3CCCc4ccccc43)c(C(=O)NCCc3ccccc3)c(C)c21
# CN1C2CCC1CC(OC(=O)c1cccc(F)c1)c1cccn1-2
#
# 93.8% valid SMILES
# -------2600--------
# CCOC(=O)c1nnc(-c2ccccn2)n1Cc1ccccc1
# COc1ccc(-c2cc(=O)c3cc(C4CCNCC4)ccc3o2)cc1
# Cc1c(Cc2ccccc2S(=O)(=O)c2ccc(F)cc2)c2cc(-n3nc(C(F)(F)F)cc3Cl)ccc2n1Cc1cccc(F)c1
# O=C(NS(=O)(=O)c1ccccc1)c1ccc(-c2csc(NS(=O)(=O)c3ccccc3)n2)cc1
# CC(=NN1CC[N+](C)(C)CC1)c1ccc(O)c(O)c1
#
# 92.2% valid SMILES
# -------2800--------
# O=C(O)CC1CCc2c(c3ccccc3n2Cc2ccc(F)cc2)C1
# N#Cc1cnc2c(NCc3ccc(F)cc3)nc(N)nc2c1N
# Cc1noc(C)c1-c1cccc(CNc2cc(C(N)=O)ccc2-c2ccn[nH]2)c1
# COc1ccc2c(=O)nc(SCc3ccc4c(c3)OCO4)oc2c1[N+](=O)[O-]
# COc1ccc(-c2ccc(C3=CC4CN(C)CC4C3C(C#N)=C(N)Oc3ccc(Cl)cc34)cc2Cl)cc1
#
# 91.0% valid SMILES
# -------3000--------
# Cc1ccccc1C(=O)Nc1ccc(N2CCN(C)CC2)cc1
# CN(C)c1cc(Cl)ncc1NC(=O)Nc1ccc(Cl)cc1
# Cc1csc(NC(=O)c2sccc2S(=O)(=O)Nc2onc(C)c2C)c1N1C(=O)c2ccccc2C1=O
# CCCOCCCNC(=O)C1CCCN1C(=O)C1(Cc2ccccc2)CCN1C
# Cc1c2cc[n+](C)cc2c(C)c2c1[nH]c1cccc(O)c12
#
# 92.6% valid SMILES
# -------3200--------
# CC(C)c1ccc(C(=O)NCC2(C(F)F)N=C(c3ccc(F)cc3)c3cccc(C)c32)cc1
# COc1c(CNCc2cccc(C)c2)c(C(C)C)nn1C
# Cc1cc(C)c2c(c1)C(O)(CC[S+](C)[O-])SS2
# Cc1cc(C(=O)N2CCC(N(C)C)C2)c(Nc2nc3ccccc3nc2C(N)=O)c(C)c1Cl
# O=c1[nH]c(=O)n(C2CC(O)C(CO)O2)cc1Br
#
# 95.3% valid SMILES
# -------3400--------
# Cc1cc(C)cc(Oc2cccc(C)n2)c1
# CC(=O)N1CCN(C2CC=CCC2)CC1
# CC(=O)C=CCC1OC1(C)C
# O=C(CN1CCN(c2ccc(Cl)cc2)CC1)c1cc(-c2ccc(F)cc2)nn1CC1CC(c2ccccc2)(c2ccccc2)c2ccccc2N1
# COc1cccc(NC(=O)CSc2nnc(CNS(=O)(=O)c3ccc(C)cc3)c(=O)n2C)c1
#
# 96.5% valid SMILES
# -------3600--------
# O=C(COc1ccccc1-c1ccccc1)N1CCN(Cc2cccc([N+](=O)[O-])c2)CC1
# CCc1ccc2nc3c(C(=O)NCCN(C)C)cccc3c(N)c2c1
# O=C(Nc1ccc(C(F)(F)F)cc1)c1csc(-c2ccccc2)n1
# CN(C)C12NC(=O)N(c3cccc(C(F)(F)F)c3)C(Cc3ccccc31)c1ccccc12
# CC(C)C(NC(=O)c1ccco1)C(=O)OCC(=O)NN=Cc1ccc([N+](=O)[O-])cc1
#
# 96.1% valid SMILES
# -------3800--------
# O=C(CSc1nnc(-c2ccncc2)n1-c1ccccc1)NCC1CCCO1
# CCCOC(C(=O)O)c1ccc2ccccc2c1
# On1nc(-c2ccccc2)c(CN2CCN(c3cccc(Cl)c3)CC2)c1Cc1ccccc1
# CCN1CCOC2c3cc(O)ccc3CCC21
# CC(C)Nc1nnc(SCC(=O)c2c(O)c3ccccc3nc2S(=O)(=O)c2ccccc2)s1
#
# 93.4% valid SMILES
# -------4000--------
# COc1ccc(-c2nnc(Sc3ccc(C#N)cc3)c3c2c2cc(C)ccc2n3C)cc1
# Cc1ccc(NCc2cncn2Cc2ccc(C#N)cc2)cc1-c1cncc2[nH]cc12
# O=C(Nc1cccc(C(=O)O)c1)C(=Cc1ccccc1)NC(=O)c1ccc(Cl)cc1
# Cc1ccc2nc(-c3ccc(NC(=O)c4ccco4)cc3)sc2c1
# CCN(CC)CCOc1ccc(C(O)(c2ccc(O)cc2)C2CCN(Cc3ccccc3)CC2)cc1
#
# 91.4% valid SMILES
# -------4200--------
# O=c1ccc(=O)n(C2CC(O)C(CO)O2)c(=O)[nH]1
# O=C(c1ccc(O)cc1)c1c(O)ccc2c1oc1cc(C(F)(F)F)ccc12
# Cc1ccc2nc(CSc3nnc(N)s3)c(O)nc2c1
# COC(=O)c1c(C)n[nH]c1-c1ccc(OCc2ccccc2C(F)(F)F)cc1
# O=C1NCc2c(-c3noc(C4CC4)n3)Oc3ccc(Br)cc31)c1ccccc12
#
# 93.0% valid SMILES
# -------4400--------
# CCOC(=O)c1cc2c(nc1C)-c1ccc(Br)cc1OC(N1CCOCC1)C2
# Cc1ccc(C(=O)CSc2cn(C)c(=O)c(=O)n2C)c(Br)c1
# CCOc1ccc(Nc2ccc(Cc3ccc(N)cc3)cc2)cc1
# COc1ccc(-c2c(O)cc(OC)c3c2OC(CN4CCN(c5ccccc5O)CC4)CC3)cc1
# COC(=O)CN1C(=O)C(=O)N(CCCSc2nnc(C3CC3)n2C)S1(=O)=O
#
# 90.6% valid SMILES
# -------4600--------
# NC(=O)C(c1ccc(Cl)cc1)c1c(O)[nH]c2ccc(Cl)cc12
# c1cc(OCCCN2CCOCC2)c2[nH]c3ccccc3c2c1
# Cc1ccccc1C(=O)NC(Cc1ccccc1)C(O)C(=O)N1CSC(C)(C)C1C(=O)N1CCSC1
# CC(NC(=O)c1ccc(Br)o1)C(=O)OCC(=O)c1ccc(Cl)cc1
# N#Cc1cc2c(=O)[nH]c(C(F)(F)F)nc2c(C2=NCCN2)n1
#
# 93.8% valid SMILES

# %% [markdown]
# # Train Agent

# %%
n_steps = 3000
scoring_function='tanimoto'
scoring_function_kwargs=None
sigma = 50
num_processes=0

# %%
def unique(arr):
    # Finds unique rows in arr and return their indices
    arr = arr.cpu().numpy()
    arr_ = np.ascontiguousarray(arr).view(np.dtype((np.void, arr.dtype.itemsize * arr.shape[1])))
    _, idxs = np.unique(arr_, return_index=True)
    if torch.cuda.is_available():
        return torch.LongTensor(np.sort(idxs)).cuda()
    return torch.LongTensor(np.sort(idxs))

def seq_to_smiles(seqs, voc):
    """Takes an output sequence from the RNN and returns the
       corresponding SMILES."""
    smiles = []
    for seq in seqs.cpu().numpy():
        smiles.append(voc.decode(seq))
    return smiles

# %%
Prior = RNN(voc,batch_size)
Agent = RNN(voc,batch_size)

# logger = VizardLog('data/logs')


Prior.rnn.load_state_dict(torch.load(f'data/PriorBest.ckpt'))
Agent.rnn.load_state_dict(torch.load(f'data/PriorBest.ckpt'))
if torch.cuda.is_available():
    Prior.rnn.to(device)
    Agent.rnn.to(device)
    Prior.rnn.eval()

scoring_function = get_scoring_function(scoring_function=scoring_function, num_processes=num_processes)
    
optimizer = torch.optim.Adam(Agent.rnn.parameters(), lr=0.0005)

# %%
bar = tqdm(range(n_steps))
bar.set_description(f'[ Training agent ]')
for step in bar:
    seqs,agent_likelihood = Agent.sample(batch_size)
    prior_likelihood,acc = Prior.forward(seqs)
    agent_likelihood,prior_likelihood = agent_likelihood.mean(axis=1),prior_likelihood.mean(axis=1)
    
    smiles = seq_to_smiles(seqs, voc)
    score = scoring_function(smiles)

    augmented_likelihood = prior_likelihood + sigma * torch.tensor(score).to(device)
    loss = torch.pow((augmented_likelihood - agent_likelihood), 2)
    loss = loss.mean()

    loss_p = (1 / agent_likelihood).mean()
    loss += 5 * 1e3 * loss_p

    # Calculate gradients and make an update to the network weights
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    bar.set_postfix({'loss':loss.item(),'acc':acc.item(),'score':sum(score)/len(score)})
    
    if (step +1) % 100 ==0:
        valid = 0
        for i,seq in enumerate(seqs):
            smile = voc.decode(seq)
            smile = voc.decode(seq)
            if Chem.MolFromSmiles(smile):
                valid += 1
            if i < 5:
                tqdm.write(smile)
        tqdm.write("\n{:>4.1f}% valid SMILES".format(100 * valid / len(seqs)))
    torch.save(Agent.rnn.state_dict(), "data/Agent.ckpt")
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# COc1ccc(NC(=O)CSc2nc3c(c(=O)n(C)c(=O)n3C)n2C)cc1OC
# Cc1ccc2nc3c(nc2c1)C(=O)C1=NNC=C13
# C=CCn1c(SCC(=O)OC(C)C)nc2sc3c(c2c1=O)CCC3
# Cc1c(NS(=O)(=O)c2ccc(Cl)s2)c(=O)n(-c2ccccc2)n1C
# Cc1cc(C(=O)OC(C)C(=O)NC2CCN(C(=N)N)CC2)c(C)o1
#
# 93.4% valid SMILES
# COc1ccc(C2CC3=Nc4c(c(OC)c(C)c(OC)c4C3=[N+](C)C)NC2)c(O)c1
# Cc1cccc(-c2cc(=O)c3ccccc3o2)n1
# Nc1ccc(S(=O)(=O)NNS(=O)(=O)c2cccc3ccccc23)cc1
# Cc1cc(C)c(OCC(=O)N2CC3(C)CC2CC(C)(C)C3)c(C)c1
# CC(OC(=O)CNc1nc2ccc(S(N)(=O)=O)cc2s1)C(=O)Nc1ccc(C(F)(F)F)cc1
#
# 91.8% valid SMILES
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 35
#      33             tqdm.write(smile)
#      34     tqdm.write("\n{:>4.1f}% valid SMILES".format(100 * valid / len(seqs)))
# ---> 35 torch.save(Agent.rnn.state_dict(), "data/Agent.ckpt")
#
# File ~\miniconda3\envs\DL\lib\site-packages\torch\serialization.py:441, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     439 if _use_new_zipfile_serialization:
#     440     with _open_zipfile_writer(f) as opened_zipfile:
# --> 441         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     442         return
#     443 else:
#
# File ~\miniconda3\envs\DL\lib\site-packages\torch\serialization.py:665, in _save(obj, zip_file, pickle_module, pickle_protocol)
#     661 # given that we copy things around anyway, we might use storage.cpu()
#     662 # this means to that to get tensors serialized, you need to implement
#     663 # .cpu() on the underlying Storage
#     664 if storage.device.type != 'cpu':
# --> 665     storage = storage.cpu()
#     666 # Now that it is on the CPU we can directly copy it into the zip file
#     667 num_bytes = storage.nbytes()
#
# KeyboardInterrupt:
